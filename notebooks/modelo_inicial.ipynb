# %% [markdown]
# NOTAS
#
# Nuestro modelo tomará como entrada todas las variables exógenas que Anisi define:
#
#
# G_a (Gasto autónomo)
#
#
# z (Productividad trabajo de mercado)
#
#
# w (Salario real)
#
#
# z_b (Productividad trabajo extramercado)
#
#
# T_i (Tiempo total disponible)
#
#
# c (Necesidad de consumo por hora)
#
# l y x (Grado de incompatibilidad e intensidad del consumo)
