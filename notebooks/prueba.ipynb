# %%
import mesa
print(f"Mesa versión {mesa.__version__} instalada correctamente!")
# Out:
# Could not import SolaraViz. If you need it, install with 'pip install --pre mesa[viz]'
# Mesa versión 3.0.3 instalada correctamente!
